# %% [markdown]
# # Learning from https://www.javatpoint.com/kivy

# %%
import kivy  # import kivy module  
from kivy.app import App # import Kivy App module to create a Kivy interface  
from kivy.uix.label import Label # import Label Module  
    
kivy.require('2.0.0')  # version required to run Kivy Application    
    

class MyKivyApp(App): # Create a class MyKivyApp  
        
      
    def build(self):   
            
        return Label(text ="Hello World !") #return a Label with text Hello World ! as a root widget         
    
    

MyKivyApp().run()  # Class MyKivyApp is initialized and run () method is called to run the App.
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\kivy\base.py in mainloop(self)
#     346             try:
# --> 347                 self.idle()
#     348                 if self.window:
#
# ~\anaconda3\lib\site-packages\kivy\base.py in idle(self)
#     414             Logger.error('Base: Application will leave')
# --> 415             self.exit()
#     416             return False
#
# ~\anaconda3\lib\site-packages\kivy\base.py in exit(self)
#     466         '''Close the main loop and close the window.'''
# --> 467         self.close()
#     468         if self.window:
#
# ~\anaconda3\lib\site-packages\kivy\base.py in close(self)
#     185         self.quit = True
# --> 186         self.stop()
#     187         self.status = 'closed'
#
# ~\anaconda3\lib\site-packages\kivy\base.py in stop(self)
#     197         for provider in reversed(self.input_providers[:]):
# --> 198             provider.stop()
#     199             if provider in self.input_providers_autoremove:
#
# ~\anaconda3\lib\site-packages\kivy\input\providers\wm_pen.py in stop(self)
#     113             self.pen = None
# --> 114             SetWindowLong_WndProc_wrapper(self.hwnd, self.old_windProc)
#     115
#
# ~\anaconda3\lib\site-packages\kivy\input\providers\wm_common.py in _closure(hWnd, wndProc)
#     111         def _closure(hWnd, wndProc):
# --> 112             oldAddr = func(hWnd, GWL_WNDPROC, cast(wndProc, c_void_p).value)
#     113             return cast(c_void_p(oldAddr), WNDPROC)
#
# ArgumentError: argument 3: <class 'TypeError'>: wrong type
#
# During handling of the above exception, another exception occurred:
#
# ArgumentError                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\kivy\base.py in runTouchApp(widget, embedded)
#     581     try:
# --> 582         EventLoop.mainloop()
#     583     finally:
#
# ~\anaconda3\lib\site-packages\kivy\base.py in mainloop(self)
#     353                 if r == ExceptionManager.RAISE:
# --> 354                     stopTouchApp()
#     355                     raise
#
# ~\anaconda3\lib\site-packages\kivy\base.py in stopTouchApp()
#     624     Logger.info('Base: Leaving application in progress...')
# --> 625     EventLoop.close()
#
# ~\anaconda3\lib\site-packages\kivy\base.py in close(self)
#     185         self.quit = True
# --> 186         self.stop()
#     187         self.status = 'closed'
#
# ~\anaconda3\lib\site-packages\kivy\base.py in stop(self)
#     197         for provider in reversed(self.input_providers[:]):
# --> 198             provider.stop()
#     199             if provider in self.input_providers_autoremove:
#
# ~\anaconda3\lib\site-packages\kivy\input\providers\wm_pen.py in stop(self)
#     113             self.pen = None
# --> 114             SetWindowLong_WndProc_wrapper(self.hwnd, self.old_windProc)
#     115
#
# ~\anaconda3\lib\site-packages\kivy\input\providers\wm_common.py in _closure(hWnd, wndProc)
#     111         def _closure(hWnd, wndProc):
# --> 112             oldAddr = func(hWnd, GWL_WNDPROC, cast(wndProc, c_void_p).value)
#     113             return cast(c_void_p(oldAddr), WNDPROC)
#
# ArgumentError: argument 3: <class 'TypeError'>: wrong type
#
# During handling of the above exception, another exception occurred:
#
# ArgumentError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1584/863743759.py in <module>
#      15
#      16
# ---> 17 MyKivyApp().run()  # Class MyKivyApp is initialized and run () method is called to run the App.
#
# ~\anaconda3\lib\site-packages\kivy\app.py in run(self)
#     948         '''
#     949         self._run_prepare()
# --> 950         runTouchApp()
#     951         self.stop()
#     952
#
# ~\anaconda3\lib\site-packages\kivy\base.py in runTouchApp(widget, embedded)
#     582         EventLoop.mainloop()
#     583     finally:
# --> 584         stopTouchApp()
#     585
#     586
#
# ~\anaconda3\lib\site-packages\kivy\base.py in stopTouchApp()
#     623         return
#     624     Logger.info('Base: Leaving application in progress...')
# --> 625     EventLoop.close()
#
# ~\anaconda3\lib\site-packages\kivy\base.py in close(self)
#     184         input providers.'''
#     185         self.quit = True
# --> 186         self.stop()
#     187         self.status = 'closed'
#     188
#
# ~\anaconda3\lib\site-packages\kivy\base.py in stop(self)
#     196         # problem happens, crashing badly without error
#     197         for provider in reversed(self.input_providers[:]):
# --> 198             provider.stop()
#     199             if provider in self.input_providers_autoremove:
#     200                 self.input_providers_autoremove.remove(provider)
#
# ~\anaconda3\lib\site-packages\kivy\input\providers\wm_pen.py in stop(self)
#     112         def stop(self):
#     113             self.pen = None
# --> 114             SetWindowLong_WndProc_wrapper(self.hwnd, self.old_windProc)
#     115
#     116     MotionEventFactory.register('wm_pen', WM_PenProvider)
#
# ~\anaconda3\lib\site-packages\kivy\input\providers\wm_common.py in _closure(hWnd, wndProc)
#     110     def SetWindowLong_WndProc_wrapper_generator(func):
#     111         def _closure(hWnd, wndProc):
# --> 112             oldAddr = func(hWnd, GWL_WNDPROC, cast(wndProc, c_void_p).value)
#     113             return cast(c_void_p(oldAddr), WNDPROC)
#     114
#
# ArgumentError: argument 3: <class 'TypeError'>: wrong type

# %%
import kivy  # import kivy module  
from kivy.app import App # import Kivy App module to create a Kivy interface  
from kivy.uix.image import Image # import image Module  
    
kivy.require('2.0.0')  # version required to run Kivy Application    
    

    
class MyKivyApp(App): # Create a class MyKivyApp  
        
      
    def build(self):   
            
        return Image(source ="C:\\Users\\Utkarsh\\Desktop\\New folder (3)\\IMG20220112171030.jpg") #return an Image as a root widget         
    
    
MyKivyApp().run()  # Class MyKivyApp is initialized and run () method is called to run the App.
# Out:
# [INFO   ] [Logger      ] Record log in C:\Users\Utkarsh\.kivy\logs\kivy_22-01-23_2.txt
# [INFO   ] [deps        ] Successfully imported "kivy_deps.gstreamer" 0.3.3
# [INFO   ] [deps        ] Successfully imported "kivy_deps.angle" 0.3.1
# [INFO   ] [deps        ] Successfully imported "kivy_deps.glew" 0.3.0
# [INFO   ] [deps        ] Successfully imported "kivy_deps.sdl2" 0.3.1
# [INFO   ] [Kivy        ] v2.0.0
# [INFO   ] [Kivy        ] Installed at "C:\Users\Utkarsh\anaconda3\lib\site-packages\kivy\__init__.py"
# [INFO   ] [Python      ] v3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]
# [INFO   ] [Python      ] Interpreter at "C:\Users\Utkarsh\anaconda3\python.exe"
# [INFO   ] [Factory     ] 186 symbols loaded
# [INFO   ] [Image       ] Providers: img_tex, img_dds, img_sdl2, img_pil (img_ffpyplayer ignored)
# [INFO   ] [Window      ] Provider: sdl2
# [INFO   ] [GL          ] Using the "OpenGL" graphics system
# [INFO   ] [GL          ] GLEW initialization succeeded
# [INFO   ] [GL          ] Backend used <glew>
# [INFO   ] [GL          ] OpenGL version <b'4.6.13559 Compatibility Profile Context 26.20.12036.8001'>
# [INFO   ] [GL          ] OpenGL vendor <b'ATI Technologies Inc.'>
# [INFO   ] [GL          ] OpenGL renderer <b'AMD Radeon(TM) R4 Graphics'>
# [INFO   ] [GL          ] OpenGL parsed version: 4, 6
# [INFO   ] [GL          ] Shading version <b'4.60'>
# [INFO   ] [GL          ] Texture max size <16384>
# [INFO   ] [GL          ] Texture max units <32>
# [INFO   ] [Window      ] auto add sdl2 input provider
# [INFO   ] [Window      ] virtual keyboard not allowed, single mode, not docked
# [INFO   ] [GL          ] NPOT texture support is available
# [INFO   ] [Base        ] Start application main loop
# [INFO   ] [Base        ] Leaving application in progress...

# %%
import kivy  # import kivy module  
from kivy.app import App # import Kivy App module to create a Kivy interface  
from kivy.uix.image import AsyncImage # import image Module  
    
kivy.require('2.0.0')  # version required to run Kivy Application    
      
   
class MyKivyApp(App): # Create a class MyKivyApp  
        
      
    def build(self):   
            
       return AsyncImage(source ="https://media.gettyimages.com/photos/stack-of-books-picture-id157482029?s=612x612") #return an Image as a root widget         
    
      #Copy the image link address.  
   
MyKivyApp().run()  # Class MyKivyApp is initialized and run () method is called to run the App.
# Out:
# [INFO   ] [Logger      ] Record log in C:\Users\Utkarsh\.kivy\logs\kivy_22-01-23_3.txt
# [INFO   ] [deps        ] Successfully imported "kivy_deps.gstreamer" 0.3.3
# [INFO   ] [deps        ] Successfully imported "kivy_deps.angle" 0.3.1
# [INFO   ] [deps        ] Successfully imported "kivy_deps.glew" 0.3.0
# [INFO   ] [deps        ] Successfully imported "kivy_deps.sdl2" 0.3.1
# [INFO   ] [Kivy        ] v2.0.0
# [INFO   ] [Kivy        ] Installed at "C:\Users\Utkarsh\anaconda3\lib\site-packages\kivy\__init__.py"
# [INFO   ] [Python      ] v3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]
# [INFO   ] [Python      ] Interpreter at "C:\Users\Utkarsh\anaconda3\python.exe"
# [INFO   ] [Factory     ] 186 symbols loaded
# [INFO   ] [Image       ] Providers: img_tex, img_dds, img_sdl2, img_pil (img_ffpyplayer ignored)
# [INFO   ] [Loader      ] using a thread pool of 2 workers
# [INFO   ] [Window      ] Provider: sdl2
# [INFO   ] [GL          ] Using the "OpenGL" graphics system
# [INFO   ] [GL          ] GLEW initialization succeeded
# [INFO   ] [GL          ] Backend used <glew>
# [INFO   ] [GL          ] OpenGL version <b'4.6.13559 Compatibility Profile Context 26.20.12036.8001'>
# [INFO   ] [GL          ] OpenGL vendor <b'ATI Technologies Inc.'>
# [INFO   ] [GL          ] OpenGL renderer <b'AMD Radeon(TM) R4 Graphics'>
# [INFO   ] [GL          ] OpenGL parsed version: 4, 6
# [INFO   ] [GL          ] Shading version <b'4.60'>
# [INFO   ] [GL          ] Texture max size <16384>
# [INFO   ] [GL          ] Texture max units <32>
# [INFO   ] [Window      ] auto add sdl2 input provider
# [INFO   ] [Window      ] virtual keyboard not allowed, single mode, not docked
# [INFO   ] [Base        ] Start application main loop
# [INFO   ] [GL          ] NPOT texture support is available
# [INFO   ] [Base        ] Leaving application in progress...

# %%
import kivy   
from kivy.app import App   
from kivy.uix.button import Button #import Button  
kivy.require("2.0.0")   
   
class kivyButtonApp(App):   
        
    def build(self):   
            
        btn = Button(text = "Press Me!")   
        return btn   
    
    
root = kivyButtonApp()   
root.run()
# Out:
# [INFO   ] [Logger      ] Record log in C:\Users\Utkarsh\.kivy\logs\kivy_22-01-23_4.txt
# [INFO   ] [deps        ] Successfully imported "kivy_deps.gstreamer" 0.3.3
# [INFO   ] [deps        ] Successfully imported "kivy_deps.angle" 0.3.1
# [INFO   ] [deps        ] Successfully imported "kivy_deps.glew" 0.3.0
# [INFO   ] [deps        ] Successfully imported "kivy_deps.sdl2" 0.3.1
# [INFO   ] [Kivy        ] v2.0.0
# [INFO   ] [Kivy        ] Installed at "C:\Users\Utkarsh\anaconda3\lib\site-packages\kivy\__init__.py"
# [INFO   ] [Python      ] v3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]
# [INFO   ] [Python      ] Interpreter at "C:\Users\Utkarsh\anaconda3\python.exe"
# [INFO   ] [Factory     ] 186 symbols loaded
# [INFO   ] [Image       ] Providers: img_tex, img_dds, img_sdl2, img_pil (img_ffpyplayer ignored)
# [INFO   ] [Text        ] Provider: sdl2
# [INFO   ] [Window      ] Provider: sdl2
# [INFO   ] [GL          ] Using the "OpenGL" graphics system
# [INFO   ] [GL          ] GLEW initialization succeeded
# [INFO   ] [GL          ] Backend used <glew>
# [INFO   ] [GL          ] OpenGL version <b'4.6.13559 Compatibility Profile Context 26.20.12036.8001'>
# [INFO   ] [GL          ] OpenGL vendor <b'ATI Technologies Inc.'>
# [INFO   ] [GL          ] OpenGL renderer <b'AMD Radeon(TM) R4 Graphics'>
# [INFO   ] [GL          ] OpenGL parsed version: 4, 6
# [INFO   ] [GL          ] Shading version <b'4.60'>
# [INFO   ] [GL          ] Texture max size <16384>
# [INFO   ] [GL          ] Texture max units <32>
# [INFO   ] [Window      ] auto add sdl2 input provider
# [INFO   ] [Window      ] virtual keyboard not allowed, single mode, not docked
# [INFO   ] [Base        ] Start application main loop
# [INFO   ] [GL          ] NPOT texture support is available
# [INFO   ] [Base        ] Leaving application in progress...

# %%
import kivy   
from kivy.app import App   
from kivy.uix.button import Button #import Button  
kivy.require("1.9.1")   
   
class kivyButtonApp(App):   
        
    def build(self):   
            
        btn = Button(text = "Press Me!", size_hint = (.2,.2), pos = (300,250))   
        return btn   
      
    
root = kivyButtonApp()   
root.run()
# Out:
# [INFO   ] [Logger      ] Record log in C:\Users\Utkarsh\.kivy\logs\kivy_22-01-23_5.txt
# [INFO   ] [deps        ] Successfully imported "kivy_deps.gstreamer" 0.3.3
# [INFO   ] [deps        ] Successfully imported "kivy_deps.angle" 0.3.1
# [INFO   ] [deps        ] Successfully imported "kivy_deps.glew" 0.3.0
# [INFO   ] [deps        ] Successfully imported "kivy_deps.sdl2" 0.3.1
# [INFO   ] [Kivy        ] v2.0.0
# [INFO   ] [Kivy        ] Installed at "C:\Users\Utkarsh\anaconda3\lib\site-packages\kivy\__init__.py"
# [INFO   ] [Python      ] v3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]
# [INFO   ] [Python      ] Interpreter at "C:\Users\Utkarsh\anaconda3\python.exe"
# [INFO   ] [Factory     ] 186 symbols loaded
# [INFO   ] [Image       ] Providers: img_tex, img_dds, img_sdl2, img_pil (img_ffpyplayer ignored)
# [INFO   ] [Text        ] Provider: sdl2
# [INFO   ] [Window      ] Provider: sdl2
# [INFO   ] [GL          ] Using the "OpenGL" graphics system
# [INFO   ] [GL          ] GLEW initialization succeeded
# [INFO   ] [GL          ] Backend used <glew>
# [INFO   ] [GL          ] OpenGL version <b'4.6.13559 Compatibility Profile Context 26.20.12036.8001'>
# [INFO   ] [GL          ] OpenGL vendor <b'ATI Technologies Inc.'>
# [INFO   ] [GL          ] OpenGL renderer <b'AMD Radeon(TM) R4 Graphics'>
# [INFO   ] [GL          ] OpenGL parsed version: 4, 6
# [INFO   ] [GL          ] Shading version <b'4.60'>
# [INFO   ] [GL          ] Texture max size <16384>
# [INFO   ] [GL          ] Texture max units <32>
# [INFO   ] [Window      ] auto add sdl2 input provider
# [INFO   ] [Window      ] virtual keyboard not allowed, single mode, not docked
# [INFO   ] [Base        ] Start application main loop
# [INFO   ] [GL          ] NPOT texture support is available
# [INFO   ] [Base        ] Leaving application in progress...

# %%
import kivy      
kivy.require("1.9.1")    
from kivy.app import App      
from kivy.uix.button import Button   
from kivy.config import Config     
Config.set('graphics', 'resizable', True)   
      
class Button_Demo(App):    
           
    def build(self):    
     
              
        btn = Button(text ="Click ME",   
                     color =(1, 0, .65, 1),   
                     background_normal = 'C:\\Users\\Utkarsh\\Desktop\\New folder (3)\\IMG20220112171030.jpg',   
                       
                     size_hint = (.4, .4),   
                     pos_hint = {"x":0.39, "y":0.3}   
                   )    
        
        return btn    
               
       
    
root = Button_Demo()    
       
root.run()
# Out:
# [INFO   ] [Logger      ] Record log in C:\Users\Utkarsh\.kivy\logs\kivy_22-01-23_6.txt
# [INFO   ] [deps        ] Successfully imported "kivy_deps.gstreamer" 0.3.3
# [INFO   ] [deps        ] Successfully imported "kivy_deps.angle" 0.3.1
# [INFO   ] [deps        ] Successfully imported "kivy_deps.glew" 0.3.0
# [INFO   ] [deps        ] Successfully imported "kivy_deps.sdl2" 0.3.1
# [INFO   ] [Kivy        ] v2.0.0
# [INFO   ] [Kivy        ] Installed at "C:\Users\Utkarsh\anaconda3\lib\site-packages\kivy\__init__.py"
# [INFO   ] [Python      ] v3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]
# [INFO   ] [Python      ] Interpreter at "C:\Users\Utkarsh\anaconda3\python.exe"
# [INFO   ] [Factory     ] 186 symbols loaded
# [INFO   ] [Image       ] Providers: img_tex, img_dds, img_sdl2, img_pil (img_ffpyplayer ignored)
# [INFO   ] [Text        ] Provider: sdl2
# [INFO   ] [Window      ] Provider: sdl2
# [INFO   ] [GL          ] Using the "OpenGL" graphics system
# [INFO   ] [GL          ] GLEW initialization succeeded
# [INFO   ] [GL          ] Backend used <glew>
# [INFO   ] [GL          ] OpenGL version <b'4.6.13559 Compatibility Profile Context 26.20.12036.8001'>
# [INFO   ] [GL          ] OpenGL vendor <b'ATI Technologies Inc.'>
# [INFO   ] [GL          ] OpenGL renderer <b'AMD Radeon(TM) R4 Graphics'>
# [INFO   ] [GL          ] OpenGL parsed version: 4, 6
# [INFO   ] [GL          ] Shading version <b'4.60'>
# [INFO   ] [GL          ] Texture max size <16384>
# [INFO   ] [GL          ] Texture max units <32>
# [INFO   ] [Window      ] auto add sdl2 input provider
# [INFO   ] [Window      ] virtual keyboard not allowed, single mode, not docked
# [INFO   ] [Base        ] Start application main loop
# [INFO   ] [GL          ] NPOT texture support is available
# [INFO   ] [Base        ] Leaving application in progress...

# %%
import kivy    
from kivy.app import App   
from kivy.uix.label import Label  #import Label Module  
    
   
class Label_Demo(App):   
    def build(self):   
         
        label1 = Label(text ="javaTpoint", font_size = 120) #Disply label on the screen  
        return label1   
    
root=Label_Demo()  
root.run()
# Out:
# [INFO   ] [Logger      ] Record log in C:\Users\Utkarsh\.kivy\logs\kivy_22-01-23_7.txt
# [INFO   ] [deps        ] Successfully imported "kivy_deps.gstreamer" 0.3.3
# [INFO   ] [deps        ] Successfully imported "kivy_deps.angle" 0.3.1
# [INFO   ] [deps        ] Successfully imported "kivy_deps.glew" 0.3.0
# [INFO   ] [deps        ] Successfully imported "kivy_deps.sdl2" 0.3.1
# [INFO   ] [Kivy        ] v2.0.0
# [INFO   ] [Kivy        ] Installed at "C:\Users\Utkarsh\anaconda3\lib\site-packages\kivy\__init__.py"
# [INFO   ] [Python      ] v3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]
# [INFO   ] [Python      ] Interpreter at "C:\Users\Utkarsh\anaconda3\python.exe"
# [INFO   ] [Factory     ] 186 symbols loaded
# [INFO   ] [Image       ] Providers: img_tex, img_dds, img_sdl2, img_pil (img_ffpyplayer ignored)
# [INFO   ] [Text        ] Provider: sdl2
# [INFO   ] [Window      ] Provider: sdl2
# [INFO   ] [GL          ] Using the "OpenGL" graphics system
# [INFO   ] [GL          ] GLEW initialization succeeded
# [INFO   ] [GL          ] Backend used <glew>
# [INFO   ] [GL          ] OpenGL version <b'4.6.13559 Compatibility Profile Context 26.20.12036.8001'>
# [INFO   ] [GL          ] OpenGL vendor <b'ATI Technologies Inc.'>
# [INFO   ] [GL          ] OpenGL renderer <b'AMD Radeon(TM) R4 Graphics'>
# [INFO   ] [GL          ] OpenGL parsed version: 4, 6
# [INFO   ] [GL          ] Shading version <b'4.60'>
# [INFO   ] [GL          ] Texture max size <16384>
# [INFO   ] [GL          ] Texture max units <32>
# [INFO   ] [Window      ] auto add sdl2 input provider
# [INFO   ] [Window      ] virtual keyboard not allowed, single mode, not docked
# [INFO   ] [Base        ] Start application main loop
# [INFO   ] [GL          ] NPOT texture support is available
# [INFO   ] [Base        ] Leaving application in progress...
