# %%
First_name = "Utkarsh"
Last_name = "Choubey"

a = input("Input your first name")
b = input("Input your last name")

if a == First_name and b == Last_name:
    print("Your name is validated")
else:
    print ("You have made some mistake!!!!!!!Please input again")
# Out:
# Input your first nameUtkarsh
# Input your last nameChoubey
# Your name is validated

# %%
initial_speed=0
final_speed=100
count=0
while initial_speed<final_speed:
    print("this is my speed")
# Out:
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# ...

# %%
initial_speed=0
final_speed=100
count=0
while initial_speed<final_speed:
    print("this is my speed")
    break
# Out:
# this is my speed

# %%
initial_speed=0
final_speed=100
count=0
while initial_speed<final_speed:
    print("this is my speed")
    count=count+1
    if count==5:
        break
# Out:
# this is my speed
# this is my speed
# this is my speed
# this is my speed
# this is my speed

# %%
i=1
j=5
while i<j:
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4

# %%
i=1
j=5
while i<j:
    print(i)
    i=i+1
# Out:
# 1
# 2
# 3
# 4

# %%
i=1
j=5
while i<j:
    print(i,\n)
    i=i+1
# Out:
#   File "C:\Users\Utkarsh\AppData\Local\Temp/ipykernel_2972/3697167491.py", line 4
#     print(i,\n)
#               ^
# SyntaxError: unexpected character after line continuation character

# %%
i=1
j=5
while i<j:
    print(i\n)
    i=i+1
# Out:
#   File "C:\Users\Utkarsh\AppData\Local\Temp/ipykernel_2972/3048805255.py", line 4
#     print(i\n)
#              ^
# SyntaxError: unexpected character after line continuation character

# %%
i=1
j=5
while i<j:
    print(i, end="")
    i=i+1
# Out:
# 1234
