# %%
import pandas as pd

titanic_train = pd.read_csv("https://d17h27t6h515a5.cloudfront.net/topher/2016/September/57e9a84c_titanic-data/titanic-data.csv", sep = ",")
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_train=titanic_train.head(156)

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
type(titanic_train)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
type(titanic_train.columns) #indexes
# Out:
# pandas.core.indexes.base.Index

# %%
type(titanic_train.dtypes) #series is almost similar to list
# Out:
# pandas.core.series.Series

# %%
dy = titanic_train.dtypes

# %%
dy
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
dy["Pclass"] #passenger id survived pclass name are same as index as0,1,2,3,.....and int64,int64,int64,object are the respective values of a particular index
# Out:
# dtype('int64')

# %%
dy[0]
# Out:
# dtype('int64')

# %%
dy[1]
# Out:
# dtype('int64')

# %%
dy[3]
# Out:
# dtype('O')

# %%
dy[0:3]
# Out:
# PassengerId    int64
# Survived       int64
# Pclass         int64
# dtype: object

# %%
dy[0:100:2]
# Out:
# PassengerId     int64
# Pclass          int64
# Sex            object
# SibSp           int64
# Ticket         object
# Cabin          object
# dtype: object

# %%
titanic_train["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 151    22.0
# 152    55.5
# 153    40.5
# 154     NaN
# 155    51.0
# Name: Age, Length: 156, dtype: float64

# %%
type(titanic_train["Age"])
# Out:
# pandas.core.series.Series

# %%
titanic_train[["Age"]]
# Out:
#       Age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 151  22.0
# 152  55.5
# 153  40.5
# 154   NaN
# 155  51.0
#
# [156 rows x 1 columns]

# %%
titanic_train[["Age"]][10:100]
# Out:
#      Age
# 10   4.0
# 11  58.0
# 12  20.0
# 13  39.0
# 14  14.0
# ..   ...
# 95   NaN
# 96  71.0
# 97  23.0
# 98  34.0
# 99  34.0
#
# [90 rows x 1 columns]

# %%
titanic_train[["Age"]][10:-1]
# Out:
#       Age
# 10    4.0
# 11   58.0
# 12   20.0
# 13   39.0
# 14   14.0
# ..    ...
# 150  51.0
# 151  22.0
# 152  55.5
# 153  40.5
# 154   NaN
#
# [145 rows x 1 columns]

# %%
titanic_train["Age"][10:-1]
# Out:
# 10      4.0
# 11     58.0
# 12     20.0
# 13     39.0
# 14     14.0
#        ...
# 150    51.0
# 151    22.0
# 152    55.5
# 153    40.5
# 154     NaN
# Name: Age, Length: 145, dtype: float64

# %%
titanic_train["Age"][-1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: -1 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12024/3517148772.py in <module>
# ----> 1 titanic_train["Age"][-1]
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ...

# %%
titanic_train[["Age"]][-1]  #backward indexing is not allowed
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: -1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
titanic_train["Age"][::2]
# Out:
# 0      22.0
# 2      26.0
# 4      35.0
# 6      54.0
# 8      27.0
#        ...
# 146    27.0
# 148    36.5
# 150    51.0
# 152    55.5
# 154     NaN
# Name: Age, Length: 78, dtype: float64

# %%
list(titanic_train["Age"][::2])
# Out:
# [22.0,
#  26.0,
#  35.0,
#  54.0,
#  27.0,
#  4.0,
#  20.0,
#  14.0,
#  2.0,
#  31.0,
#  35.0,
#  15.0,
#  8.0,
#  nan,
#  nan,
#  40.0,
#  nan,
#  28.0,
#  nan,
#  18.0,
#  40.0,
#  nan,
#  19.0,
#  nan,
#  nan,
#  7.0,
#  49.0,
#  65.0,
#  21.0,
#  5.0,
#  22.0,
#  45.0,
#  nan,
#  29.0,
#  17.0,
#  32.0,
#  21.0,
#  32.0,
#  nan,
#  0.83,
#  22.0,
#  nan,
#  17.0,
#  16.0,
#  23.0,
#  29.0,
#  46.0,
#  59.0,
#  71.0,
#  34.0,
#  28.0,
#  21.0,
#  37.0,
#  21.0,
#  38.0,
#  47.0,
#  22.0,
#  17.0,
#  70.5,
#  24.0,
#  21.0,
#  32.5,
#  54.0,
#  nan,
#  nan,
#  33.0,
#  47.0,
#  25.0,
#  19.0,
#  16.0,
#  nan,
#  24.0,
#  18.0,
#  27.0,
#  36.5,
#  51.0,
#  55.5,
#  nan]

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_train.describe
# Out:
# <bound method NDFrame.describe of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
titanic_train.describe()
# describe gives description about numerical data only
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
type(titanic_train.describe)
# Out:
# method

# %%
type(titanic_train.describe())
# Out:
# pandas.core.frame.DataFrame

# %%
# filtering categorical column

titanic_train.dtypes=="object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
titanic_train.dtypes[titanic_train.dtypes=="object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
titanic_train.dtypes[titanic_train.dtypes=="object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
indexes = titanic_train.dtypes[titanic_train.dtypes=="object"].index

# %%
titanic_train[indexes]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female
# 152                                   Meo, Mr. Alfonzo    male
# 153                    van Billiard, Mr. Austin Blyler    male
# 154                              Olsen, Mr. Ole Martin    male
# 155                        Williams, Mr. Charles Duane    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
titanic_train_categorical = titanic_train[indexes]

# %%
titanic_train_categorical.describe()
# Out:
#                            Name   Sex Ticket        Cabin Embarked
# count                       156   156    156           31      155
# unique                      156     2    145           28        3
# top     Braund, Mr. Owen Harris  male   2651  C23 C25 C27        S
# freq                          1   100      2            2      110

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_train["Name", "Fare"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Name', 'Fare')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
titanic_train[["Name", "Fare"]]
# Out:
#                                                   Name     Fare
# 0                              Braund, Mr. Owen Harris   7.2500
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833
# 2                               Heikkinen, Miss. Laina   7.9250
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000
# 4                             Allen, Mr. William Henry   8.0500
# ..                                                 ...      ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  66.6000
# 152                                   Meo, Mr. Alfonzo   8.0500
# 153                    van Billiard, Mr. Austin Blyler  14.5000
# 154                              Olsen, Mr. Ole Martin   7.3125
# 155                        Williams, Mr. Charles Duane  61.3792
#
# [156 rows x 2 columns]

# %%
titanic_train["Age"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154     True
# 155    False
# Name: Age, Length: 156, dtype: bool

# %%
titanic_train[["Age"]].isnull()
# Out:
#        Age
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# ..     ...
# 151  False
# 152  False
# 153  False
# 154   True
# 155  False
#
# [156 rows x 1 columns]

# %%
import numpy as np

# %%
np.where(titanic_train["Age"].isnull()==True)
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154], dtype=int64),)

# %%
titanic_train[titanic_train["Age"].isnull()==True]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
titanic_train_age_null = np.where(titanic_train["Age"].isnull()==True)

# %%
titanic_train_age_null
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154], dtype=int64),)

# %%
#row-wise data filtration

titanic_train.iloc[titanic_train_age_null] #iloc = integer location i.e. index location
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
titanic_train.iloc[17]
# Out:
# PassengerId                              18
# Survived                                  1
# Pclass                                    2
# Name           Williams, Mr. Charles Eugene
# Sex                                    male
# Age                                     NaN
# SibSp                                     0
# Parch                                     0
# Ticket                               244373
# Fare                                   13.0
# Cabin                                   NaN
# Embarked                                  S
# Name: 17, dtype: object

# %%
titanic_train.iloc[[17]]
# Out:
#     PassengerId  Survived  Pclass                          Name   Sex  Age  \
# 17           18         1       2  Williams, Mr. Charles Eugene  male  NaN
#
#     SibSp  Parch  Ticket  Fare Cabin Embarked
# 17      0      0  244373  13.0   NaN        S

# %%
titanic_train.iloc[[1,2,3,6,7]]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 6            7         0       1
# 7            8         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S

# %%
titanic_train.iloc[np.where(titanic_train["Fare"] == max(titanic_train["Fare"]))]["Name"]
# Out:
# 27    Fortune, Mr. Charles Alexander
# 88        Fortune, Miss. Mabel Helen
# Name: Name, dtype: object

# %%
titanic_train[titanic_train["Fare"] == max(titanic_train["Fare"])]["Name"]
# Out:
# 27    Fortune, Mr. Charles Alexander
# 88        Fortune, Miss. Mabel Helen
# Name: Name, dtype: object

# %%
titanic_train[titanic_train["Fare"] == max(titanic_train["Fare"])][["Name"]]
# Out:
#                               Name
# 27  Fortune, Mr. Charles Alexander
# 88      Fortune, Miss. Mabel Helen

# %%
titanic_train["Age"] == 24.0
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154    False
# 155    False
# Name: Age, Length: 156, dtype: bool

# %%
titanic_train[titanic_train["Age"] == 24.0]
# Out:
#      PassengerId  Survived  Pclass  \
# 89            90         0       3
# 118          119         0       1
# 127          128         1       3
# 139          140         0       1
# 142          143         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 89                              Celotti, Mr. Francesco    male  24.0      0
# 118                           Baxter, Mr. Quigg Edmond    male  24.0      0
# 127                          Madsen, Mr. Fridtjof Arne    male  24.0      0
# 139                                 Giglio, Mr. Victor    male  24.0      0
# 142  Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...  female  24.0      1
#
#      Parch            Ticket      Fare    Cabin Embarked
# 89       0            343275    8.0500      NaN        S
# 118      1          PC 17558  247.5208  B58 B60        C
# 127      0           C 17369    7.1417      NaN        S
# 139      0          PC 17593   79.2000      B86        C
# ...

# %%
titanic_train[titanic_train["Age"] == 24.0]["Name"]
# Out:
# 89                                Celotti, Mr. Francesco
# 118                             Baxter, Mr. Quigg Edmond
# 127                            Madsen, Mr. Fridtjof Arne
# 139                                   Giglio, Mr. Victor
# 142    Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...
# Name: Name, dtype: object

# %%
titanic_train[titanic_train["Age"] == 24.0][["Name"]]
# Out:
#                                                   Name
# 89                              Celotti, Mr. Francesco
# 118                           Baxter, Mr. Quigg Edmond
# 127                          Madsen, Mr. Fridtjof Arne
# 139                                 Giglio, Mr. Victor
# 142  Hakkarainen, Mrs. Pekka Pietari (Elin Matilda ...

# %%
titanic_train[titanic_train["Age"] == titanic_train["Age"].min()]
# Out:
#     PassengerId  Survived  Pclass                           Name   Sex   Age  \
# 78           79         1       2  Caldwell, Master. Alden Gates  male  0.83
#
#     SibSp  Parch  Ticket  Fare Cabin Embarked
# 78      0      2  248738  29.0   NaN        S

# %%
titanic_train[titanic_train["Age"] == titanic_train["Age"].min()]["Name"]
# Out:
# 78    Caldwell, Master. Alden Gates
# Name: Name, dtype: object

# %%
titanic_train[titanic_train["Age"] == titanic_train["Age"].min()][["Name"]]
# Out:
#                              Name
# 78  Caldwell, Master. Alden Gates

# %%
titanic_train["Age"][titanic_train["Cabin"].isnull()==True]
# Out:
# 0      22.0
# 2      26.0
# 4      35.0
# 5       NaN
# 7       2.0
#        ...
# 150    51.0
# 152    55.5
# 153    40.5
# 154     NaN
# 155    51.0
# Name: Age, Length: 125, dtype: float64

# %%
titanic_train[["Age"]][titanic_train["Cabin"].isnull()==True]
# Out:
#       Age
# 0    22.0
# 2    26.0
# 4    35.0
# 5     NaN
# 7     2.0
# ..    ...
# 150  51.0
# 152  55.5
# 153  40.5
# 154   NaN
# 155  51.0
#
# [125 rows x 1 columns]

# %%
titanic_train["Age"][titanic_train["Cabin"] == "Nan"]
# Out:
# Series([], Name: Age, dtype: float64)

# %%
titanic_train[titanic_train["Cabin"] == "Nan"]["Age"]
# Out:
# Series([], Name: Age, dtype: float64)

# %%
titanic_train.iloc[np.where(titanic_train["Cabin"] == "Nan")]["Age"]
# Out:
# Series([], Name: Age, dtype: float64)

# %%
titanic_train.iloc[np.where(titanic_train["Cabin"].isnull()==True)]["Age"]
# Out:
# 0      22.0
# 2      26.0
# 4      35.0
# 5       NaN
# 7       2.0
#        ...
# 150    51.0
# 152    55.5
# 153    40.5
# 154     NaN
# 155    51.0
# Name: Age, Length: 125, dtype: float64

# %%
titanic_train.iloc[np.where(titanic_train["Cabin"].isnull()==True)][["Age"]]
# Out:
#       Age
# 0    22.0
# 2    26.0
# 4    35.0
# 5     NaN
# 7     2.0
# ..    ...
# 150  51.0
# 152  55.5
# 153  40.5
# 154   NaN
# 155  51.0
#
# [125 rows x 1 columns]

# %%
titanic_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
titanic_train[titanic_train["Survived"]==1 & titanic_train["Sex"]=="male"]["Name"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     301         #  (xint or xbool) and (yint or bool)
# --> 302         result = op(x, y)
#     303     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\roperator.py in rand_(left, right)
#      51 def rand_(left, right):
# ---> 52     return operator.and_(right, left)
#      53
#
# TypeError: unsupported operand type(s) for &: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     315             try:
# --> 316                 result = libops.scalar_binop(x, y, op)
#     317             except (
#
# ...

# %%
titanic_train[(titanic_train["Survived"]==1) & (titanic_train["Sex"]=="male")]["Name"]
# Out:
# 17                     Williams, Mr. Charles Eugene
# 21                            Beesley, Mr. Lawrence
# 23                     Sloper, Mr. William Thompson
# 36                                 Mamee, Mr. Hanna
# 55                                Woolner, Mr. Hugh
# 65                         Moubarek, Master. Gerios
# 74                                    Bing, Mr. Lee
# 78                    Caldwell, Master. Alden Gates
# 81                      Sheerlinck, Mr. Jan Baptist
# 97                  Greenfield, Mr. William Bertram
# 107                          Moss, Mr. Albert Johan
# 125                    Nicola-Yarred, Master. Elias
# 127                       Madsen, Mr. Fridtjof Arne
# 146    Andersson, Mr. August Edvard ("Wennerstrom")
# Name: Name, dtype: object

# %%
titanic_train.iloc[np.where(titanic_train["Survived"]==1 & titanic_train["Sex"]=="male")]["Name"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     301         #  (xint or xbool) and (yint or bool)
# --> 302         result = op(x, y)
#     303     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\roperator.py in rand_(left, right)
#      51 def rand_(left, right):
# ---> 52     return operator.and_(right, left)
#      53
#
# TypeError: unsupported operand type(s) for &: 'int' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     315             try:
# --> 316                 result = libops.scalar_binop(x, y, op)
#     317             except (
#
# ...

# %%
titanic_train.iloc[np.where((titanic_train["Survived"]==1) & (titanic_train["Sex"]=="male"))]["Name"]
# Out:
# 17                     Williams, Mr. Charles Eugene
# 21                            Beesley, Mr. Lawrence
# 23                     Sloper, Mr. William Thompson
# 36                                 Mamee, Mr. Hanna
# 55                                Woolner, Mr. Hugh
# 65                         Moubarek, Master. Gerios
# 74                                    Bing, Mr. Lee
# 78                    Caldwell, Master. Alden Gates
# 81                      Sheerlinck, Mr. Jan Baptist
# 97                  Greenfield, Mr. William Bertram
# 107                          Moss, Mr. Albert Johan
# 125                    Nicola-Yarred, Master. Elias
# 127                       Madsen, Mr. Fridtjof Arne
# 146    Andersson, Mr. August Edvard ("Wennerstrom")
# Name: Name, dtype: object

# %%
titanic_train["Name"].iloc[np.where((titanic_train["Survived"]==1) & (titanic_train["Sex"]=="male"))]
# Out:
# 17                     Williams, Mr. Charles Eugene
# 21                            Beesley, Mr. Lawrence
# 23                     Sloper, Mr. William Thompson
# 36                                 Mamee, Mr. Hanna
# 55                                Woolner, Mr. Hugh
# 65                         Moubarek, Master. Gerios
# 74                                    Bing, Mr. Lee
# 78                    Caldwell, Master. Alden Gates
# 81                      Sheerlinck, Mr. Jan Baptist
# 97                  Greenfield, Mr. William Bertram
# 107                          Moss, Mr. Albert Johan
# 125                    Nicola-Yarred, Master. Elias
# 127                       Madsen, Mr. Fridtjof Arne
# 146    Andersson, Mr. August Edvard ("Wennerstrom")
# Name: Name, dtype: object

# %%
titanic_train.Name[(titanic_train.Survived==1) & (titanic_train.Sex=="male")]
# Out:
# 17                     Williams, Mr. Charles Eugene
# 21                            Beesley, Mr. Lawrence
# 23                     Sloper, Mr. William Thompson
# 36                                 Mamee, Mr. Hanna
# 55                                Woolner, Mr. Hugh
# 65                         Moubarek, Master. Gerios
# 74                                    Bing, Mr. Lee
# 78                    Caldwell, Master. Alden Gates
# 81                      Sheerlinck, Mr. Jan Baptist
# 97                  Greenfield, Mr. William Bertram
# 107                          Moss, Mr. Albert Johan
# 125                    Nicola-Yarred, Master. Elias
# 127                       Madsen, Mr. Fridtjof Arne
# 146    Andersson, Mr. August Edvard ("Wennerstrom")
# Name: Name, dtype: object

# %%
titanic_train[(titanic_train["Survived"]==1) & (titanic_train["Sex"]=="male")][["Name"]]
# Out:
#                                              Name
# 17                   Williams, Mr. Charles Eugene
# 21                          Beesley, Mr. Lawrence
# 23                   Sloper, Mr. William Thompson
# 36                               Mamee, Mr. Hanna
# 55                              Woolner, Mr. Hugh
# 65                       Moubarek, Master. Gerios
# 74                                  Bing, Mr. Lee
# 78                  Caldwell, Master. Alden Gates
# 81                    Sheerlinck, Mr. Jan Baptist
# 97                Greenfield, Mr. William Bertram
# 107                        Moss, Mr. Albert Johan
# 125                  Nicola-Yarred, Master. Elias
# 127                     Madsen, Mr. Fridtjof Arne
# 146  Andersson, Mr. August Edvard ("Wennerstrom")

# %%
titanic_train["New_column"] = "sudh"
# Out:
# C:\Users\Utkarsh\AppData\Local\Temp/ipykernel_12024/1073294595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic_train["New_column"] = "sudh"

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked New_column
# 0      0         A/5 21171   7.2500   NaN        S       sudh
# 1      0          PC 17599  71.2833   C85        C       sudh
# 2      0  STON/O2. 3101282   7.9250   NaN        S       sudh
# 3      0            113803  53.1000  C123        S       sudh
# ...

# %%
l = [1,2,3,4,5]

# %%
pd.Series(l)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
d = {"name": "sudh", "title":"kumar","mail_id": "sudh@gmail.com" }

# %%
pd.DataFrame(d, index=["name", "title"])
# Out:
#        name  title         mail_id
# name   sudh  kumar  sudh@gmail.com
# title  sudh  kumar  sudh@gmail.com

# %%
pd.Series(d)
# Out:
# name                 sudh
# title               kumar
# mail_id    sudh@gmail.com
# dtype: object

# %%
arr = np.random.randn(3,4)

# %%
pd.DataFrame(arr)
# Out:
#           0         1         2         3
# 0  0.551270 -1.183101 -0.354459 -1.545789
# 1  0.654150 -0.662251 -1.154417  0.339960
# 2 -0.674937 -0.584428 -1.880531  1.359433

# %%
pd.Series(arr) #error due to multidimension array
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12024/2396573727.py in <module>
# ----> 1 pd.Series(arr)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     437                     data = data.copy()
#     438             else:
# --> 439                 data = sanitize_array(data, index, dtype, copy)
#     440
#     441                 manager = get_option("mode.data_manager")
#
# ~\anaconda3\lib\site-packages\pandas\core\construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure, allow_2d)
#     574                 subarr = maybe_infer_to_datetimelike(subarr)
#     575
# --> 576     subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     577
#     578     if isinstance(subarr, np.ndarray):
#
# ...

# %%
 pd.Series(np.array([4,5,6,7,8]))
# Out:
# 0    4
# 1    5
# 2    6
# 3    7
# 4    8
# dtype: int32

# %%
 pd.Series(np.array([4,5,6,7,8]), index = ["a","b", "sudh", "kumar", "c"])
# Out:
# a        4
# b        5
# sudh     6
# kumar    7
# c        8
# dtype: int32

# %%
ser =  pd.Series(np.array([4,5,6,7,8]), index = ["a","b", "sudh", "kumar", "c"])

# %%
ser["sudh"]
# Out:
# 6

# %%
ser.iloc["sudh"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12024/693588422.py in <module>
# ----> 1 ser.iloc["sudh"]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1561             key = item_from_zerodim(key)
#    1562             if not is_integer(key):
# -> 1563                 raise TypeError("Cannot index by location index with a non-integer key")
#    1564
#    1565             # validate the location
#
# TypeError: Cannot index by location index with a non-integer key

# %%
ser.iloc[2]
# Out:
# 6

# %%
ser.loc["sudh"]
# Out:
# 6

# %%
ser1 =  pd.Series(np.array([4,5,6,7,8]), index = [45,51,62,75,83])

# %%
ser1
# Out:
# 45    4
# 51    5
# 62    6
# 75    7
# 83    8
# dtype: int32

# %%
ser1.iloc[51] #iloc always take default indexces i.e. 0,1,2,3,....
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12024/1158159280.py in <module>
# ----> 1 ser1.iloc[51]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1564
#    1565             # validate the location
# -> 1566             self._validate_integer(key, axis)
#    1567
#    1568             return self.obj._ixs(key, axis=axis)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1498         len_axis = len(self.obj._get_axis(axis))
# ...

# %%
ser1.iloc[1]
# Out:
# 5

# %%
ser1.loc[51]
# Out:
# 5

# %%
np.random.randint(3,6,(4,5))
# Out:
# array([[3, 5, 3, 5, 3],
#        [3, 5, 3, 5, 3],
#        [3, 3, 4, 5, 5],
#        [5, 5, 3, 3, 3]])

# %%
pd.DataFrame(np.random.randint(3,6,(4,5)))
# Out:
#    0  1  2  3  4
# 0  3  3  5  4  5
# 1  4  4  3  5  3
# 2  4  4  5  4  3
# 3  5  5  5  3  5

# %%
pd.DataFrame(np.random.randint(3,6,(4,5)), index = ["a","b","c","d"],columns = ["x", "y", "z", "u", "v"])
# Out:
#    x  y  z  u  v
# a  4  4  4  4  5
# b  4  5  4  5  5
# c  3  3  5  5  5
# d  3  4  3  4  3

# %%
df = pd.DataFrame(np.random.randint(3,6,(4,5)), index = ["a","b","c","d"],columns = ["x", "y", "z", "u", "v"])

# %%
df.loc["c":"d", "z":"u"]
# Out:
#    z  u
# c  3  3
# d  3  3

# %%
df.loc["c":, "z":"u"]
# Out:
#    z  u
# c  3  3
# d  3  3

# %%
df.loc[["c","d"], ["z","u"]]
# Out:
#    z  u
# c  3  3
# d  3  3

# %%
df.loc[["c":"d"], ["z":"u"]]
# Out:
#   File "C:\Users\Utkarsh\AppData\Local\Temp/ipykernel_12024/2720187420.py", line 1
#     df.loc[["c":"d"], ["z":"u"]]
#                ^
# SyntaxError: invalid syntax

# %%
df
# Out:
#    x  y  z  u  v
# a  4  5  3  4  5
# b  3  5  3  4  4
# c  3  5  3  3  4
# d  5  4  3  3  5

# %%
 df["new"]=df["x"]+df.y

# %%
df
# Out:
#    x  y  z  u  v  new
# a  4  5  3  4  5    9
# b  3  5  3  4  4    8
# c  3  5  3  3  4    8
# d  5  4  3  3  5    9

# %%
df.drop("x") #axis = 0 means row and axis = 1 means columns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12024/3892012460.py in <module>
# ----> 1 df.drop("x") #axis = 0 means row and axis = 1 means columns
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df.drop("x",axis = 1)
# Out:
#    y  z  u  v  new
# a  5  3  4  5    9
# b  5  3  4  4    8
# c  5  3  3  4    8
# d  4  3  3  5    9

# %%
df #changes are not permanently saved
# Out:
#    x  y  z  u  v  new
# a  4  5  3  4  5    9
# b  3  5  3  4  4    8
# c  3  5  3  3  4    8
# d  5  4  3  3  5    9

# %%
df.drop("x",axis = 1, inplace = True)

# %%
df
# Out:
#    y  z  u  v  new
# a  5  3  4  5    9
# b  5  3  4  4    8
# c  5  3  3  4    8
# d  4  3  3  5    9

# %%
df.drop("c", inplace = True)

# %%
df.drop("a")
# Out:
#    y  z  u  v  new
# b  5  3  4  4    8
# d  4  3  3  5    9

# %%
np.random.rand(4,5)
# Out:
# array([[0.95209823, 0.99790924, 0.81174138, 0.59088149, 0.75822129],
#        [0.66762507, 0.4910338 , 0.51653209, 0.57820809, 0.55498175],
#        [0.54771076, 0.91678353, 0.9321761 , 0.4404479 , 0.83396644],
#        [0.27438501, 0.28517765, 0.69548238, 0.01505886, 0.95127021]])

# %%
pd.DataFrame(np.random.rand(4,5))
# Out:
#           0         1         2         3         4
# 0  0.676859  0.547552  0.256710  0.114319  0.884301
# 1  0.134141  0.463621  0.405047  0.290757  0.331668
# 2  0.340306  0.348423  0.873019  0.395672  0.205497
# 3  0.141819  0.398899  0.731466  0.490861  0.895416

# %%
pd.DataFrame(np.random.rand(4,5), index = ["a","b","c","d"],columns = ["x", "y", "z", "u", "v"])
# Out:
#           x         y         z         u         v
# a  0.811414  0.526143  0.611517  0.499113  0.223149
# b  0.441604  0.761024  0.123159  0.879051  0.900496
# c  0.745868  0.659658  0.887072  0.849288  0.063258
# d  0.535052  0.534197  0.271418  0.853089  0.746042

# %%
np.random.seed(23)
df = pd.DataFrame(np.random.randn(4,5), index = ["a","b","c","d"],columns = ["x", "y", "z", "u", "v"])

# %%
df
# Out:
#           x         y         z         u         v
# a  0.666988  0.025813 -0.777619  0.948634  0.701672
# b -1.051082 -0.367548 -1.137460 -1.322148  1.772258
# c -0.347459  0.670140  0.322272  0.060343 -1.043450
# d -1.009942  0.441736  1.128877 -1.838068 -0.938769

# %%
type(df.shape)
# Out:
# tuple

# %%
df.values[df.values<0]
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
df.values[df.iloc[0:5]<0]
# Out:
# array([-0.77761941, -1.05108156, -0.36754812, -1.13745969, -1.32214752,
#        -0.34745899, -1.04345   , -1.00994188, -1.83806777, -0.93876863])

# %%
i,j = df.shape
l=[]
for i in range(i):
    for j in range(j):
        if df.iloc[i][j]<0:
            l.append(df.iloc[i][j])
l
# Out:
# [-0.7776194131918178,
#  -1.0510815639071178,
#  -0.3675481161171661,
#  -1.1374596907250272,
#  -1.3221475225908594,
#  -0.34745899102186334,
#  -1.0099418765878465]

# %%
l=df.values[df<0]

for i in df.index:
    for j in df.columns:
        if df.loc[i][j] in l:
            print(f"index is {i}, column is {j} and the respective value is {df.loc[i][j]} ")
# Out:
# index is a, column is z and the respective value is -0.7776194131918178
# index is b, column is x and the respective value is -1.0510815639071178
# index is b, column is y and the respective value is -0.3675481161171661
# index is b, column is z and the respective value is -1.1374596907250272
# index is b, column is u and the respective value is -1.3221475225908594
# index is c, column is x and the respective value is -0.34745899102186334
# index is c, column is v and the respective value is -1.0434500017467254
# index is d, column is x and the respective value is -1.0099418765878465
# index is d, column is u and the respective value is -1.8380677677579502
# index is d, column is v and the respective value is -0.9387686311201282

# %%
l=df.values[df.values<0]

for i in df.index:
    for j in df.columns:
        if df.loc[i][j] in l:
            print(f"index is {i}, column is {j} and the respective value is {df.loc[i][j]} ")
# Out:
# index is a, column is z and the respective value is -0.7776194131918178
# index is b, column is x and the respective value is -1.0510815639071178
# index is b, column is y and the respective value is -0.3675481161171661
# index is b, column is z and the respective value is -1.1374596907250272
# index is b, column is u and the respective value is -1.3221475225908594
# index is c, column is x and the respective value is -0.34745899102186334
# index is c, column is v and the respective value is -1.0434500017467254
# index is d, column is x and the respective value is -1.0099418765878465
# index is d, column is u and the respective value is -1.8380677677579502
# index is d, column is v and the respective value is -0.9387686311201282

# %%
l=df.values[df.values<0]

for row in df.index:
    for column in df.columns:
        if df[row][column] in l:
            print(f"index is {row}, column is {column} and the respective value is {df[row][column]} ")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'a'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
d = {'key1':[1,2,3,4,np.nan],"key2":["sudh" ,"kumar" , np.nan,5,6] ,'key3' :[np.nan,np.nan,np.nan,3,8]}
df = pd.DataFrame(d)

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna() 
# dropping all rows if any one of its column has NaN value
# Out:
#    key1 key2  key3
# 3   4.0    5   3.0

# %%
df.dropna(axis=1) 
# dropping all columns if any one of its row has NaN value
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
d = {'key1':[1,2,3,4,np.nan],"key2":["sudh" ,"kumar" , 4,5,6] ,'key3' :[np.nan,np.nan,np.nan,3,8]}
df = pd.DataFrame(d)

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0      4   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(axis=1)
# Out:
#     key2
# 0   sudh
# 1  kumar
# 2      4
# 3      5
# 4      6

# %%
d = {'key1':[1,2,3,4,np.nan],"key2":["sudh" ,"kumar" , np.nan,5,6] ,'key3' :[np.nan,np.nan,np.nan,3,8]}
df = pd.DataFrame(d)

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=1)
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=2)
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
df.dropna(thresh=3)
# Out:
#    key1 key2  key3
# 3   4.0    5   3.0

# %%
df.dropna(thresh=4)
# Out:
# Empty DataFrame
# Columns: [key1, key2, key3]
# Index: []

# %%
df.dropna(thresh=5) #this threshold fn is looking for atleast that many non-NaN values
#and if its is satisfied, it will execute previous fn
# Out:
# Empty DataFrame
# Columns: [key1, key2, key3]
# Index: []

# %%
df.fillna(567)
# Out:
#     key1   key2   key3
# 0    1.0   sudh  567.0
# 1    2.0  kumar  567.0
# 2    3.0    567  567.0
# 3    4.0      5    3.0
# 4  567.0      6    8.0

# %%
df.fillna(value=df["key1"].mean)
# Out:
#                                                 key1  \
# 0                                                1.0
# 1                                                2.0
# 2                                                3.0
# 3                                                4.0
# 4  <bound method NDFrame._add_numeric_operations....
#
#                                                 key2  \
# 0                                               sudh
# 1                                              kumar
# 2  <bound method NDFrame._add_numeric_operations....
# 3                                                  5
# 4                                                  6
#
#                                                 key3
# 0  <bound method NDFrame._add_numeric_operations....
# 1  <bound method NDFrame._add_numeric_operations....
# 2  <bound method NDFrame._add_numeric_operations....
# 3                                                3.0
# 4                                                8.0

# %%
df.fillna(value=df["key1"].mean())
# Out:
#    key1   key2  key3
# 0   1.0   sudh   2.5
# 1   2.0  kumar   2.5
# 2   3.0    2.5   2.5
# 3   4.0      5   3.0
# 4   2.5      6   8.0

# %%
df
# Out:
#    key1   key2  key3
# 0   1.0   sudh   NaN
# 1   2.0  kumar   NaN
# 2   3.0    NaN   NaN
# 3   4.0      5   3.0
# 4   NaN      6   8.0

# %%
d1 = {'name' :['sudh' , 'visal' , 'umang', 'vishal' ,'umang'],"mail_id" :["sudh@gmail.com", "vishal@gmail.com",'umang@gmail.com','vishal@gmail.com','umang@gmail.com'],
     'salary' :[100,200,500,200,500]}

df = pd.DataFrame(d1)
df
# Out:
#      name           mail_id  salary
# 0    sudh    sudh@gmail.com     100
# 1   visal  vishal@gmail.com     200
# 2   umang   umang@gmail.com     500
# 3  vishal  vishal@gmail.com     200
# 4   umang   umang@gmail.com     500

# %%
df.groupby("name").mean()
# Out:
#         salary
# name
# sudh     100.0
# umang    500.0
# visal    200.0
# vishal   200.0

# %%
df.groupby("mail_id").mean()
# Out:
#                   salary
# mail_id
# sudh@gmail.com     100.0
# umang@gmail.com    500.0
# vishal@gmail.com   200.0

# %%
df.groupby("name").sum()
# Out:
#         salary
# name
# sudh       100
# umang     1000
# visal      200
# vishal     200

# %%
df.groupby("mail_id").sum()
# Out:
#                   salary
# mail_id
# sudh@gmail.com       100
# umang@gmail.com     1000
# vishal@gmail.com     400

# %%
df.groupby("mail_id").describe()
# Out:
#                  salary
#                   count   mean  std    min    25%    50%    75%    max
# mail_id
# sudh@gmail.com      1.0  100.0  NaN  100.0  100.0  100.0  100.0  100.0
# umang@gmail.com     2.0  500.0  0.0  500.0  500.0  500.0  500.0  500.0
# vishal@gmail.com    2.0  200.0  0.0  200.0  200.0  200.0  200.0  200.0

# %%
df.groupby("mail_id").describe().loc[["umang@gmail.com"]]
# Out:
#                 salary
#                  count   mean  std    min    25%    50%    75%    max
# mail_id
# umang@gmail.com    2.0  500.0  0.0  500.0  500.0  500.0  500.0  500.0

# %%
df.groupby("mail_id").describe().loc[["umang@gmail.com"]]["salary"]["mean"]
# Out:
# mail_id
# umang@gmail.com    500.0
# Name: mean, dtype: float64

# %%
df.groupby("mail_id").describe().loc[["umang@gmail.com"]]["salary"][["mean"]]
# Out:
#                   mean
# mail_id
# umang@gmail.com  500.0

# %%
df.groupby("mail_id").describe().loc["umang@gmail.com"]
# Out:
# salary  count      2.0
#         mean     500.0
#         std        0.0
#         min      500.0
#         25%      500.0
#         50%      500.0
#         75%      500.0
#         max      500.0
# Name: umang@gmail.com, dtype: float64

# %%
df.groupby("mail_id").describe().loc["umang@gmail.com"][[1]]
# Out:
# salary  mean    500.0
# Name: umang@gmail.com, dtype: float64

# %%
df.groupby("mail_id").describe().loc["umang@gmail.com"][1]
# Out:
# 500.0

# %%
df.groupby("mail_id").describe().T #converting rows into columns and columns into rows
# Out:
# mail_id       sudh@gmail.com  umang@gmail.com  vishal@gmail.com
# salary count             1.0              2.0               2.0
#        mean            100.0            500.0             200.0
#        std               NaN              0.0               0.0
#        min             100.0            500.0             200.0
#        25%             100.0            500.0             200.0
#        50%             100.0            500.0             200.0
#        75%             100.0            500.0             200.0
#        max             100.0            500.0             200.0

# %%
arr1 = np.random.randn(3,4)

arr2 = np.random.randn(3,4)

arr3 = np.random.randn(3,4)

df1 = pd.DataFrame(arr1,columns=["A","B","C","D"],index = [0,1,2])

df2 = pd.DataFrame(arr2,columns=["A","B","C","D"],index = [3,4,5])

df3 = pd.DataFrame(arr3,columns=["A","B","C","D"],index = [6,7,8])

# %%
df1
# Out:
#           A         B         C         D
# 0 -0.201841  1.045371  0.538162  0.812119
# 1  0.241106 -0.952510 -0.136267  1.267248
# 2  0.173634 -1.223255  1.415320  0.457711

# %%
df2
# Out:
#           A         B         C         D
# 3  0.728876  1.968435 -0.547788 -0.679418
# 4 -2.506230  0.146960  0.606195 -0.022539
# 5  0.013422  0.935945  0.420623  0.411620

# %%
df3
# Out:
#           A         B         C         D
# 6 -0.071324 -0.045438  1.040886 -0.094035
# 7 -0.420844 -0.551989 -0.121098  0.190141
# 8  0.512137  0.131538 -0.331617 -1.632386

# %%
df4 = pd.concat([df1,df2,df3]) # row-wise concatenation because axis = 0 by defaultdf4
df4
# Out:
#           A         B         C         D
# 0 -0.201841  1.045371  0.538162  0.812119
# 1  0.241106 -0.952510 -0.136267  1.267248
# 2  0.173634 -1.223255  1.415320  0.457711
# 3  0.728876  1.968435 -0.547788 -0.679418
# 4 -2.506230  0.146960  0.606195 -0.022539
# 5  0.013422  0.935945  0.420623  0.411620
# 6 -0.071324 -0.045438  1.040886 -0.094035
# 7 -0.420844 -0.551989 -0.121098  0.190141
# 8  0.512137  0.131538 -0.331617 -1.632386

# %%
pd.concat([df1,df2,df3],axis=1)
# Out:
#           A         B         C         D         A         B         C  \
# 0 -0.201841  1.045371  0.538162  0.812119       NaN       NaN       NaN
# 1  0.241106 -0.952510 -0.136267  1.267248       NaN       NaN       NaN
# 2  0.173634 -1.223255  1.415320  0.457711       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN  0.728876  1.968435 -0.547788
# 4       NaN       NaN       NaN       NaN -2.506230  0.146960  0.606195
# 5       NaN       NaN       NaN       NaN  0.013422  0.935945  0.420623
# 6       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 7       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#           D         A         B         C         D
# 0       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN
# ...

# %%
df1 = pd.DataFrame(arr1,columns=["A","B","C","D"],index = [0,1,2])

df2 = pd.DataFrame(arr2,columns=["A","B","C","D"],index = [0,1,2])

df3 = pd.DataFrame(arr3,columns=["A","B","C","D"],index = [0,1,2])

# %%
pd.concat([df1,df2,df3])
# Out:
#           A         B         C         D
# 0 -0.201841  1.045371  0.538162  0.812119
# 1  0.241106 -0.952510 -0.136267  1.267248
# 2  0.173634 -1.223255  1.415320  0.457711
# 0  0.728876  1.968435 -0.547788 -0.679418
# 1 -2.506230  0.146960  0.606195 -0.022539
# 2  0.013422  0.935945  0.420623  0.411620
# 0 -0.071324 -0.045438  1.040886 -0.094035
# 1 -0.420844 -0.551989 -0.121098  0.190141
# 2  0.512137  0.131538 -0.331617 -1.632386

# %%
pd.concat([df1,df2,df3], axis = 1)
# Out:
#           A         B         C         D         A         B         C  \
# 0 -0.201841  1.045371  0.538162  0.812119  0.728876  1.968435 -0.547788
# 1  0.241106 -0.952510 -0.136267  1.267248 -2.506230  0.146960  0.606195
# 2  0.173634 -1.223255  1.415320  0.457711  0.013422  0.935945  0.420623
#
#           D         A         B         C         D
# 0 -0.679418 -0.071324 -0.045438  1.040886 -0.094035
# 1 -0.022539 -0.420844 -0.551989 -0.121098  0.190141
# 2  0.411620  0.512137  0.131538 -0.331617 -1.632386

# %%
df4 = pd.concat([df1,df2,df3])

# %%
df5 = pd.concat([df1,df2,df3],axis=1)

# %%
df4.iloc[0] #only 1st row is accessible
# Out:
# A   -0.201841
# B    1.045371
# C    0.538162
# D    0.812119
# Name: 0, dtype: float64

# %%
df4.loc[0]
# Out:
#           A         B         C         D
# 0 -0.201841  1.045371  0.538162  0.812119
# 0  0.728876  1.968435 -0.547788 -0.679418
# 0 -0.071324 -0.045438  1.040886 -0.094035

# %%
df5["A"] #all the columns are available ,,,but i don't want this
# Out:
#           A         A         A
# 0 -0.201841  0.728876 -0.071324
# 1  0.241106 -2.506230 -0.420844
# 2  0.173634  0.013422  0.512137

# %%
df5.iloc[:,4]
# Out:
# 0    0.728876
# 1   -2.506230
# 2    0.013422
# Name: A, dtype: float64

# %%
df1 = pd.DataFrame(arr1,columns=["A","B","C","D"],index = [0,1,2])

df2 = pd.DataFrame(arr2,columns=["A","B","C","D"],index = [3,4,5])

df3 = pd.DataFrame(arr3,columns=["A","B","C","D"],index = [6,7,8])

# %%
pd.concat([df1,df2,df3],axis =1)
# Out:
#           A         B         C         D         A         B         C  \
# 0 -0.201841  1.045371  0.538162  0.812119       NaN       NaN       NaN
# 1  0.241106 -0.952510 -0.136267  1.267248       NaN       NaN       NaN
# 2  0.173634 -1.223255  1.415320  0.457711       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN  0.728876  1.968435 -0.547788
# 4       NaN       NaN       NaN       NaN -2.506230  0.146960  0.606195
# 5       NaN       NaN       NaN       NaN  0.013422  0.935945  0.420623
# 6       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 7       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#           D         A         B         C         D
# 0       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN
# ...

# %%
pd.concat([df1,df2,df3])
# Out:
#           A         B         C         D
# 0 -0.201841  1.045371  0.538162  0.812119
# 1  0.241106 -0.952510 -0.136267  1.267248
# 2  0.173634 -1.223255  1.415320  0.457711
# 3  0.728876  1.968435 -0.547788 -0.679418
# 4 -2.506230  0.146960  0.606195 -0.022539
# 5  0.013422  0.935945  0.420623  0.411620
# 6 -0.071324 -0.045438  1.040886 -0.094035
# 7 -0.420844 -0.551989 -0.121098  0.190141
# 8  0.512137  0.131538 -0.331617 -1.632386

# %%
pd.concat([df1,df2,df3],axis =1, fillna = 0.0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12024/3244252745.py in <module>
# ----> 1 pd.concat([df1,df2,df3],axis =1, fillna = 0.0)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# TypeError: concat() got an unexpected keyword argument 'fillna'

# %%
pd.concat([df1,df2,df3],axis =1).fillna(0.0)
# Out:
#           A         B         C         D         A         B         C  \
# 0 -0.201841  1.045371  0.538162  0.812119  0.000000  0.000000  0.000000
# 1  0.241106 -0.952510 -0.136267  1.267248  0.000000  0.000000  0.000000
# 2  0.173634 -1.223255  1.415320  0.457711  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  0.728876  1.968435 -0.547788
# 4  0.000000  0.000000  0.000000  0.000000 -2.506230  0.146960  0.606195
# 5  0.000000  0.000000  0.000000  0.000000  0.013422  0.935945  0.420623
# 6  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 7  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#           D         A         B         C         D
# 0  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000
# ...

# %%
df1
# Out:
#           A         B         C         D
# 0 -0.201841  1.045371  0.538162  0.812119
# 1  0.241106 -0.952510 -0.136267  1.267248
# 2  0.173634 -1.223255  1.415320  0.457711

# %%
df2
# Out:
#           A         B         C         D
# 3  0.728876  1.968435 -0.547788 -0.679418
# 4 -2.506230  0.146960  0.606195 -0.022539
# 5  0.013422  0.935945  0.420623  0.411620

# %%
np.random.seed(23)
arr1 = np.random.randn(3,4)
np.random.seed(23)
arr2 = np.random.randn(3,4)
df11 = pd.DataFrame(arr1,columns=["A","B","C","D"],index = [0,1,2])
df22 = pd.DataFrame(arr2,columns=["D","E","F","G"],index = [3,4,5])

# %%
df11
# Out:
#           A         B         C         D
# 0  0.666988  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460
# 2 -1.322148  1.772258 -0.347459  0.670140

# %%
df22
# Out:
#           D         E         F         G
# 3  0.666988  0.025813 -0.777619  0.948634
# 4  0.701672 -1.051082 -0.367548 -1.137460
# 5 -1.322148  1.772258 -0.347459  0.670140

# %%
pd.merge(df11,df22)
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, E, F, G]
# Index: []

# %%
np.random.seed(23)
arr1 = np.random.randn(3,4)
np.random.seed(23)
arr2 = np.random.randn(3,4)
df11 = pd.DataFrame(arr1,columns=["A","B","C","D"],index = [0,1,2])
df22 = pd.DataFrame(arr2,columns=["A","E","F","G"],index = [3,4,5])

# %%
pd.merge(df11,df22)
# Out:
#           A         B         C         D         E         F         G
# 0  0.666988  0.025813 -0.777619  0.948634  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460 -1.051082 -0.367548 -1.137460
# 2 -1.322148  1.772258 -0.347459  0.670140  1.772258 -0.347459  0.670140

# %%
pd.merge(df11,df22, on = "A")
# Out:
#           A         B         C         D         E         F         G
# 0  0.666988  0.025813 -0.777619  0.948634  0.025813 -0.777619  0.948634
# 1  0.701672 -1.051082 -0.367548 -1.137460 -1.051082 -0.367548 -1.137460
# 2 -1.322148  1.772258 -0.347459  0.670140  1.772258 -0.347459  0.670140

# %%
pd.merge(df11,df22, on = "B")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12024/2998645679.py in <module>
# ----> 1 pd.merge(df11,df22, on = "B")
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     104     validate: str | None = None,
#     105 ) -> DataFrame:
# --> 106     op = _MergeOperation(
#     107         left,
#     108         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     697             self.right_join_keys,
#     698             self.join_names,
# --> 699         ) = self._get_merge_keys()
#     700
# ...

# %%
df1 = pd.DataFrame({'key': ['K0', 'K8', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})
   
df2 = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                          'C': ['C0', 'C1', 'C2', 'C3'],
                          'D': ['D0', 'D1', 'D2', 'D3']})

# %%
df1
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K8  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
df2
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
pd.merge(df1,df2,on= 'key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K2  A2  B2  C2  D2
# 2  K3  A3  B3  C3  D3

# %%
pd.merge(df1,df2,on= 'key', how ="left")
# Out:
#   key   A   B    C    D
# 0  K0  A0  B0   C0   D0
# 1  K8  A1  B1  NaN  NaN
# 2  K2  A2  B2   C2   D2
# 3  K3  A3  B3   C3   D3

# %%
pd.merge(df1,df2,on= 'key', how ="right")
# Out:
#   key    A    B   C   D
# 0  K0   A0   B0  C0  D0
# 1  K1  NaN  NaN  C1  D1
# 2  K2   A2   B2  C2  D2
# 3  K3   A3   B3  C3  D3

# %%
pd.merge(df1,df2,on= 'key', how ="outer")
# Out:
#   key    A    B    C    D
# 0  K0   A0   B0   C0   D0
# 1  K8   A1   B1  NaN  NaN
# 2  K2   A2   B2   C2   D2
# 3  K3   A3   B3   C3   D3
# 4  K1  NaN  NaN   C1   D1

# %%
df1 = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                        'A': ['A0', 'A1', 'A2', 'A3'],
                        'B': ['B0', 'B1', 'B2', 'B3']})
    
df2 = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                               'key2': ['K0', 'K0', 'K0', 'K0'],
                                  'C': ['C0', 'C1', 'C2', 'C3'],
                                  'D': ['D0', 'D1', 'D2', 'D3']})

# %%
df1
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
df2
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
pd.merge(df1,df2,on = ['key1','key2'])
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                      index=['K0', 'K1', 'K2']) 

df2 = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                    'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

# %%
df1
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
df2
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %%
df1.join(df2,how = 'outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %%
df2.join(df1,how = 'outer')
# Out:
#       C    D    A    B
# K0   C0   D0   A0   B0
# K1  NaN  NaN   A1   B1
# K2   C2   D2   A2   B2
# K3   C3   D3  NaN  NaN

# %%
df1.join(df2) #by default join = left
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2
